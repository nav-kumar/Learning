# %% [markdown]
# "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# NAVEEN KUMAR PABBATHI
# Software Engineer

# %% [markdown]
# I am interested in Data Science because I would love to contribute in the health care industry to provide valuable data driven models to healthcare professionals.

# %% [markdown]
# Print My favourite Sport

# %%
print("My favourite sport is Cricket!")
# Out:
# My favourite sport is Cricket!

# %% [markdown]
# <ol>
#   <li>Eat</li>
#   <li>Work</li>
#   <li>Sleep</li>
# </ol>
#  <a href="https://www.google.com">Visit W3Schools.com!</a>
#  <table>
#     <tr>
#         <th>Sport</th>
#         <th>Person</th>
#         <th>Hobby</th>
#     </tr>
#     <tr>
#         <td>Cricket</td>
#         <td>Virat</td>
#         <td>Drawing</td>
#     </tr>
#     </table>
